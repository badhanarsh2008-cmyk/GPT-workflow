# %% [markdown]
# spaCy and pipeline

# %%
import spacy

# %%
s1 = "Hi my name is arsh."

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# !python -m spacy download en_core_web_sm

# %%
doc = nlp(s1)

# %%
print(doc)
# Out:
# Hi my name is arsh.

# %%
for token in doc:
    print(token)
# Out:
# Hi
# my
# name
# is
# arsh
# .

# %%
print(len(doc))
# Out:
# 6
